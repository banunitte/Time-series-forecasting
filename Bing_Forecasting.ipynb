# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
#import xgboost as xgb
import operator
import matplotlib
matplotlib.use("Agg") #Needed to save figures
import matplotlib.pyplot as plt

# %%
types = {'CompetitionOpenSinceYear': np.dtype(int),
         'CompetitionOpenSinceMonth': np.dtype(int),
         'StateHoliday': np.dtype(str),
         'Promo2SinceWeek': np.dtype(int),
         'SchoolHoliday': np.dtype(float),
         'PromoInterval': np.dtype(str)}

# %% [markdown]
# ### Reading the csv file

# %%
train = pd.read_csv("C:/Users/bbalakrishna/Downloads/rossmann-store-sales/train.csv", parse_dates=[2],dtype=types)

# %%
train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0

# %% [markdown]
# ### Check if any null values are present in the data

# %%
print(train.apply(lambda x : sum(x.isnull())))
# Out:
# Exception ignored in: <function DMatrix.__del__ at 0x000002C35DB42E18>
# Traceback (most recent call last):
#   File "C:\Users\bbalakrishna\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py", line 482, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
train.StateHoliday.value_counts()
# Out:
# 0    986159
# a     20260
# b      6690
# c      4100
# Name: StateHoliday, dtype: int64

# %% [markdown]
# #### StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. . a = public holiday, b = Easter holiday, c = Christmas, 0 = None

# %%
### machine learning algorithms only work with numbers so convert characters to numbers
mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
train.StateHoliday.replace(mappings, inplace=True)

# %%
## filling the null values with 0
train.fillna(0, inplace=True)

# %%
train['Year'] = train.Date.dt.year
train['Month'] = train.Date.dt.month
train['Day'] = train.Date.dt.day
train['DayOfWeek'] = train.Date.dt.dayofweek
train['WeekOfYear'] = train.Date.dt.weekofyear

# %%
train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1             0
# 1      2          4 2015-07-31   6064        625     1      1             0
# 2      3          4 2015-07-31   8314        821     1      1             0
# 3      4          4 2015-07-31  13995       1498     1      1             0
# 4      5          4 2015-07-31   4822        559     1      1             0
#
#    SchoolHoliday  Year  Month  Day  WeekOfYear
# 0            1.0  2015      7   31          31
# 1            1.0  2015      7   31          31
# 2            1.0  2015      7   31          31
# 3            1.0  2015      7   31          31
# 4            1.0  2015      7   31          31

# %%
features = ['Year','Month','Day','DayOfWeek','WeekOfYear','StateHoliday']

# %% [markdown]
# ### preparing the test data

# %%
test = pd.read_csv("C:/Users/bbalakrishna/Downloads/rossmann-store-sales/test.csv", parse_dates=[3],dtype=types)

# %%
### machine learning algorithms only work with numbers so convert characters to numbers
mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
test.StateHoliday.replace(mappings, inplace=True)
test.fillna(0, inplace=True)
test['Year'] = test.Date.dt.year
test['Month'] = test.Date.dt.month
test['Day'] = test.Date.dt.day
test['DayOfWeek'] = test.Date.dt.dayofweek
test['WeekOfYear'] = test.Date.dt.weekofyear

# %%
test.head()
# Out:
#    Id  Store  DayOfWeek       Date  Open  Promo  StateHoliday  SchoolHoliday  \
# 0   1      1          3 2015-09-17   1.0      1             0            0.0
# 1   2      3          3 2015-09-17   1.0      1             0            0.0
# 2   3      7          3 2015-09-17   1.0      1             0            0.0
# 3   4      8          3 2015-09-17   1.0      1             0            0.0
# 4   5      9          3 2015-09-17   1.0      1             0            0.0
#
#    Year  Month  Day  WeekOfYear
# 0  2015      9   17          38
# 1  2015      9   17          38
# 2  2015      9   17          38
# 3  2015      9   17          38
# 4  2015      9   17          38

# %%
test[features].head()
# Out:
#    Year  Month  Day  DayOfWeek  WeekOfYear  StateHoliday
# 0  2015      9   17          3          38             0
# 1  2015      9   17          3          38             0
# 2  2015      9   17          3          38             0
# 3  2015      9   17          3          38             0
# 4  2015      9   17          3          38             0

# %%
print('training data processed')

params = {"objective": "reg:linear",
          "booster" : "gbtree",
          "eta": 0.3,
          "max_depth": 10,
          "subsample": 0.9,
          "colsample_bytree": 0.7,
          "silent": 1,
          "seed": 1301
          }
num_boost_round = 300
# Out:
# training data processed

# %%
import xgboost as xgb

# %%
train[features].head()
# Out:
#    Year  Month  Day  DayOfWeek  WeekOfYear  StateHoliday
# 0  2015      7   31          4          31             0
# 1  2015      7   31          4          31             0
# 2  2015      7   31          4          31             0
# 3  2015      7   31          4          31             0
# 4  2015      7   31          4          31             0

# %% [markdown]
# #### for building the model we will only use features = ['Year','Month','Day','DayOfWeek','WeekOfYear','StateHoliday']

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#...     X, y, test_size=0.33, random_state=42)
print("Train a XGBoost model")
X_train, X_valid,y_train, y_valid= train_test_split(train[features],train.Sales, test_size=0.012, random_state=10)

dtrain = xgb.DMatrix(X_train[features], y_train)
dvalid = xgb.DMatrix(X_valid[features], y_valid)
# Out:
# Train a XGBoost model

# %%
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, \
  early_stopping_rounds=100,  verbose_eval=True)
# Out:
# [0]	train-rmse:5503.89	eval-rmse:5620.58
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 100 rounds.
# [1]	train-rmse:4507.16	eval-rmse:4625.07
# [2]	train-rmse:3671.76	eval-rmse:3800.2
# [3]	train-rmse:3173.55	eval-rmse:3308.45
# [4]	train-rmse:2897.38	eval-rmse:3036.06
# [5]	train-rmse:2748.45	eval-rmse:2889.85
# [6]	train-rmse:2666.04	eval-rmse:2807.01
# [7]	train-rmse:2618.2	eval-rmse:2758.79
# [8]	train-rmse:2597.4	eval-rmse:2735.31
# [9]	train-rmse:2574.87	eval-rmse:2710.87
# [10]	train-rmse:2560.32	eval-rmse:2695.06
# [11]	train-rmse:2554.44	eval-rmse:2688.68
# [12]	train-rmse:2542.66	eval-rmse:2676.9
# [13]	train-rmse:2541	eval-rmse:2674.72
# [14]	train-rmse:2535.38	eval-rmse:2669.03
# [15]	train-rmse:2533.2	eval-rmse:2666.42
# [16]	train-rmse:2532.67	eval-rmse:2665.54
# [17]	train-rmse:2530.45	eval-rmse:2662.49
# [18]	train-rmse:2530.15	eval-rmse:2662.06
# [19]	train-rmse:2529.16	eval-rmse:2660.89
# [20]	train-rmse:2529.01	eval-rmse:2660.53
# [21]	train-rmse:2528.06	eval-rmse:2659.61
# [22]	train-rmse:2527.28	eval-rmse:2658.44
# [23]	train-rmse:2527.17	eval-rmse:2658.4
# [24]	train-rmse:2526.43	eval-rmse:2657.47
# [25]	train-rmse:2525.93	eval-rmse:2656.97
# [26]	train-rmse:2525.89	eval-rmse:2656.93
# [27]	train-rmse:2525.66	eval-rmse:2656.74
# [28]	train-rmse:2525.48	eval-rmse:2656.6
# [29]	train-rmse:2525.1	eval-rmse:2656.46
# [30]	train-rmse:2524.98	eval-rmse:2656.41
# [31]	train-rmse:2524.96	eval-rmse:2656.35
# [32]	train-rmse:2524.85	eval-rmse:2656.35
# [33]	train-rmse:2524.85	eval-rmse:2656.34
# [34]	train-rmse:2524.8	eval-rmse:2656.32
# [35]	train-rmse:2524.77	eval-rmse:2656.29
# [36]	train-rmse:2524.7	eval-rmse:2656.24
# [37]	train-rmse:2524.62	eval-rmse:2656.22
# [38]	train-rmse:2524.59	eval-rmse:2656.08
# [39]	train-rmse:2524.58	eval-rmse:2656.02
# [40]	train-rmse:2524.53	eval-rmse:2655.93
# [41]	train-rmse:2524.51	eval-rmse:2655.93
# [42]	train-rmse:2524.49	eval-rmse:2655.98
# [43]	train-rmse:2524.49	eval-rmse:2655.94
# [44]	train-rmse:2524.48	eval-rmse:2655.96
# [45]	train-rmse:2524.48	eval-rmse:2655.97
# [46]	train-rmse:2524.47	eval-rmse:2655.91
# [47]	train-rmse:2524.47	eval-rmse:2655.88
# [48]	train-rmse:2524.47	eval-rmse:2655.88
# [49]	train-rmse:2524.46	eval-rmse:2655.87
# [50]	train-rmse:2524.46	eval-rmse:2655.87
# [51]	train-rmse:2524.46	eval-rmse:2655.85
# [52]	train-rmse:2524.45	eval-rmse:2655.89
# [53]	train-rmse:2524.45	eval-rmse:2655.87
# [54]	train-rmse:2524.45	eval-rmse:2655.86
# [55]	train-rmse:2524.44	eval-rmse:2655.79
# [56]	train-rmse:2524.44	eval-rmse:2655.85
# [57]	train-rmse:2524.44	eval-rmse:2655.8
# [58]	train-rmse:2524.44	eval-rmse:2655.8
# [59]	train-rmse:2524.43	eval-rmse:2655.84
# [60]	train-rmse:2524.43	eval-rmse:2655.83
# [61]	train-rmse:2524.43	eval-rmse:2655.85
# [62]	train-rmse:2524.43	eval-rmse:2655.9
# [63]	train-rmse:2524.43	eval-rmse:2655.94
# [64]	train-rmse:2524.43	eval-rmse:2655.9
# [65]	train-rmse:2524.43	eval-rmse:2655.92
# [66]	train-rmse:2524.43	eval-rmse:2655.88
# [67]	train-rmse:2524.43	eval-rmse:2655.97
# [68]	train-rmse:2524.43	eval-rmse:2655.97
# [69]	train-rmse:2524.43	eval-rmse:2655.95
# [70]	train-rmse:2524.43	eval-rmse:2655.97
# [71]	train-rmse:2524.43	eval-rmse:2655.98
# [72]	train-rmse:2524.43	eval-rmse:2655.92
# [73]	train-rmse:2524.43	eval-rmse:2655.96
# [74]	train-rmse:2524.43	eval-rmse:2655.86
# [75]	train-rmse:2524.43	eval-rmse:2655.84
# [76]	train-rmse:2524.43	eval-rmse:2655.9
# [77]	train-rmse:2524.43	eval-rmse:2655.93
# [78]	train-rmse:2524.43	eval-rmse:2655.92
# [79]	train-rmse:2524.43	eval-rmse:2656
# [80]	train-rmse:2524.43	eval-rmse:2655.87
# [81]	train-rmse:2524.43	eval-rmse:2655.86
# [82]	train-rmse:2524.43	eval-rmse:2655.86
# [83]	train-rmse:2524.42	eval-rmse:2655.88
# [84]	train-rmse:2524.42	eval-rmse:2655.9
# [85]	train-rmse:2524.42	eval-rmse:2655.89
# [86]	train-rmse:2524.42	eval-rmse:2655.88
# [87]	train-rmse:2524.42	eval-rmse:2655.86
# [88]	train-rmse:2524.42	eval-rmse:2655.87
# [89]	train-rmse:2524.42	eval-rmse:2655.85
# [90]	train-rmse:2524.42	eval-rmse:2655.92
# [91]	train-rmse:2524.42	eval-rmse:2655.89
# [92]	train-rmse:2524.42	eval-rmse:2655.86
# [93]	train-rmse:2524.43	eval-rmse:2655.74
# [94]	train-rmse:2524.42	eval-rmse:2655.74
# [95]	train-rmse:2524.42	eval-rmse:2655.72
# [96]	train-rmse:2524.42	eval-rmse:2655.74
# [97]	train-rmse:2524.42	eval-rmse:2655.76
# [98]	train-rmse:2524.42	eval-rmse:2655.68
# [99]	train-rmse:2524.42	eval-rmse:2655.86
# [100]	train-rmse:2524.42	eval-rmse:2655.84
# [101]	train-rmse:2524.43	eval-rmse:2655.94
# [102]	train-rmse:2524.43	eval-rmse:2655.97
# [103]	train-rmse:2524.43	eval-rmse:2655.9
# [104]	train-rmse:2524.42	eval-rmse:2655.86
# [105]	train-rmse:2524.42	eval-rmse:2655.79
# [106]	train-rmse:2524.42	eval-rmse:2655.83
# [107]	train-rmse:2524.42	eval-rmse:2655.77
# [108]	train-rmse:2524.42	eval-rmse:2655.76
# [109]	train-rmse:2524.43	eval-rmse:2655.81
# [110]	train-rmse:2524.42	eval-rmse:2655.81
# [111]	train-rmse:2524.42	eval-rmse:2655.9
# [112]	train-rmse:2524.42	eval-rmse:2655.95
# [113]	train-rmse:2524.42	eval-rmse:2655.88
# [114]	train-rmse:2524.42	eval-rmse:2655.82
# [115]	train-rmse:2524.43	eval-rmse:2655.91
# [116]	train-rmse:2524.42	eval-rmse:2655.99
# [117]	train-rmse:2524.42	eval-rmse:2655.96
# [118]	train-rmse:2524.42	eval-rmse:2655.94
# [119]	train-rmse:2524.42	eval-rmse:2655.97
# [120]	train-rmse:2524.42	eval-rmse:2655.9
# [121]	train-rmse:2524.42	eval-rmse:2655.88
# [122]	train-rmse:2524.42	eval-rmse:2655.89
# [123]	train-rmse:2524.42	eval-rmse:2655.84
# [124]	train-rmse:2524.42	eval-rmse:2655.79
# [125]	train-rmse:2524.42	eval-rmse:2655.79
# [126]	train-rmse:2524.42	eval-rmse:2655.81
# [127]	train-rmse:2524.42	eval-rmse:2655.92
# [128]	train-rmse:2524.42	eval-rmse:2655.95
# [129]	train-rmse:2524.42	eval-rmse:2655.95
# [130]	train-rmse:2524.42	eval-rmse:2655.9
# [131]	train-rmse:2524.42	eval-rmse:2655.91
# [132]	train-rmse:2524.42	eval-rmse:2655.91
# [133]	train-rmse:2524.42	eval-rmse:2655.88
# [134]	train-rmse:2524.42	eval-rmse:2655.89
# [135]	train-rmse:2524.43	eval-rmse:2655.8
# [136]	train-rmse:2524.43	eval-rmse:2655.83
# [137]	train-rmse:2524.42	eval-rmse:2655.89
# [138]	train-rmse:2524.42	eval-rmse:2655.97
# [139]	train-rmse:2524.42	eval-rmse:2655.92
# [140]	train-rmse:2524.42	eval-rmse:2655.89
# [141]	train-rmse:2524.42	eval-rmse:2655.92
# [142]	train-rmse:2524.42	eval-rmse:2655.95
# [143]	train-rmse:2524.42	eval-rmse:2655.9
# [144]	train-rmse:2524.42	eval-rmse:2655.9
# [145]	train-rmse:2524.42	eval-rmse:2655.95
# [146]	train-rmse:2524.42	eval-rmse:2655.89
# [147]	train-rmse:2524.42	eval-rmse:2655.88
# [148]	train-rmse:2524.42	eval-rmse:2655.85
# [149]	train-rmse:2524.42	eval-rmse:2655.89
# [150]	train-rmse:2524.42	eval-rmse:2655.92
# [151]	train-rmse:2524.42	eval-rmse:2655.84
# [152]	train-rmse:2524.42	eval-rmse:2655.78
# [153]	train-rmse:2524.42	eval-rmse:2655.81
# [154]	train-rmse:2524.42	eval-rmse:2655.88
# [155]	train-rmse:2524.43	eval-rmse:2655.84
# [156]	train-rmse:2524.42	eval-rmse:2656
# [157]	train-rmse:2524.43	eval-rmse:2656.06
# [158]	train-rmse:2524.43	eval-rmse:2656.09
# [159]	train-rmse:2524.43	eval-rmse:2656.14
# [160]	train-rmse:2524.43	eval-rmse:2656.09
# [161]	train-rmse:2524.42	eval-rmse:2656.06
# [162]	train-rmse:2524.42	eval-rmse:2656.16
# [163]	train-rmse:2524.43	eval-rmse:2656.2
# [164]	train-rmse:2524.43	eval-rmse:2656.2
# [165]	train-rmse:2524.42	eval-rmse:2656.18
# [166]	train-rmse:2524.42	eval-rmse:2656.09
# [167]	train-rmse:2524.43	eval-rmse:2656.06
# [168]	train-rmse:2524.42	eval-rmse:2656
# [169]	train-rmse:2524.42	eval-rmse:2655.92
# [170]	train-rmse:2524.43	eval-rmse:2655.83
# [171]	train-rmse:2524.43	eval-rmse:2655.79
# [172]	train-rmse:2524.42	eval-rmse:2655.69
# [173]	train-rmse:2524.42	eval-rmse:2655.67
# [174]	train-rmse:2524.42	eval-rmse:2655.65
# [175]	train-rmse:2524.42	eval-rmse:2655.69
# [176]	train-rmse:2524.42	eval-rmse:2655.75
# [177]	train-rmse:2524.42	eval-rmse:2655.79
# [178]	train-rmse:2524.42	eval-rmse:2655.78
# [179]	train-rmse:2524.42	eval-rmse:2655.79
# [180]	train-rmse:2524.42	eval-rmse:2655.73
# [181]	train-rmse:2524.42	eval-rmse:2655.72
# [182]	train-rmse:2524.42	eval-rmse:2655.66
# [183]	train-rmse:2524.42	eval-rmse:2655.72
# [184]	train-rmse:2524.42	eval-rmse:2655.77
# [185]	train-rmse:2524.42	eval-rmse:2655.77
# [186]	train-rmse:2524.42	eval-rmse:2655.75
# [187]	train-rmse:2524.42	eval-rmse:2655.74
# [188]	train-rmse:2524.42	eval-rmse:2655.84
# [189]	train-rmse:2524.42	eval-rmse:2655.88
# [190]	train-rmse:2524.42	eval-rmse:2655.83
# [191]	train-rmse:2524.42	eval-rmse:2655.76
# [192]	train-rmse:2524.42	eval-rmse:2655.75
# [193]	train-rmse:2524.42	eval-rmse:2655.74
# [194]	train-rmse:2524.42	eval-rmse:2655.77
# [195]	train-rmse:2524.42	eval-rmse:2655.69
# [196]	train-rmse:2524.42	eval-rmse:2655.66
# [197]	train-rmse:2524.42	eval-rmse:2655.72
# [198]	train-rmse:2524.42	eval-rmse:2655.74
# [199]	train-rmse:2524.42	eval-rmse:2655.71
# [200]	train-rmse:2524.42	eval-rmse:2655.63
# [201]	train-rmse:2524.42	eval-rmse:2655.65
# [202]	train-rmse:2524.42	eval-rmse:2655.67
# [203]	train-rmse:2524.42	eval-rmse:2655.66
# [204]	train-rmse:2524.42	eval-rmse:2655.66
# [205]	train-rmse:2524.42	eval-rmse:2655.67
# [206]	train-rmse:2524.42	eval-rmse:2655.71
# [207]	train-rmse:2524.42	eval-rmse:2655.74
# [208]	train-rmse:2524.42	eval-rmse:2655.72
# [209]	train-rmse:2524.42	eval-rmse:2655.73
# [210]	train-rmse:2524.42	eval-rmse:2655.85
# [211]	train-rmse:2524.42	eval-rmse:2655.89
# [212]	train-rmse:2524.42	eval-rmse:2655.92
# [213]	train-rmse:2524.42	eval-rmse:2655.92
# [214]	train-rmse:2524.42	eval-rmse:2655.89
# [215]	train-rmse:2524.42	eval-rmse:2655.82
# [216]	train-rmse:2524.43	eval-rmse:2655.81
# [217]	train-rmse:2524.43	eval-rmse:2655.79
# [218]	train-rmse:2524.43	eval-rmse:2655.76
# [219]	train-rmse:2524.42	eval-rmse:2655.83
# [220]	train-rmse:2524.43	eval-rmse:2655.8
# [221]	train-rmse:2524.43	eval-rmse:2655.82
# [222]	train-rmse:2524.43	eval-rmse:2655.87
# [223]	train-rmse:2524.42	eval-rmse:2655.84
# [224]	train-rmse:2524.42	eval-rmse:2655.81
# [225]	train-rmse:2524.42	eval-rmse:2655.8
# [226]	train-rmse:2524.42	eval-rmse:2655.82
# [227]	train-rmse:2524.42	eval-rmse:2655.82
# [228]	train-rmse:2524.42	eval-rmse:2655.85
# [229]	train-rmse:2524.42	eval-rmse:2655.77
# [230]	train-rmse:2524.42	eval-rmse:2655.72
# [231]	train-rmse:2524.42	eval-rmse:2655.73
# [232]	train-rmse:2524.42	eval-rmse:2655.72
# [233]	train-rmse:2524.42	eval-rmse:2655.71
# [234]	train-rmse:2524.42	eval-rmse:2655.73
# [235]	train-rmse:2524.42	eval-rmse:2655.79
# [236]	train-rmse:2524.42	eval-rmse:2655.88
# [237]	train-rmse:2524.42	eval-rmse:2655.84
# [238]	train-rmse:2524.42	eval-rmse:2655.98
# [239]	train-rmse:2524.42	eval-rmse:2656.01
# [240]	train-rmse:2524.42	eval-rmse:2655.89
# [241]	train-rmse:2524.42	eval-rmse:2655.88
# [242]	train-rmse:2524.42	eval-rmse:2655.84
# [243]	train-rmse:2524.42	eval-rmse:2655.88
# [244]	train-rmse:2524.42	eval-rmse:2655.93
# [245]	train-rmse:2524.42	eval-rmse:2655.87
# [246]	train-rmse:2524.42	eval-rmse:2655.82
# [247]	train-rmse:2524.42	eval-rmse:2655.77
# [248]	train-rmse:2524.42	eval-rmse:2655.73
# [249]	train-rmse:2524.42	eval-rmse:2655.81
# [250]	train-rmse:2524.42	eval-rmse:2655.74
# [251]	train-rmse:2524.43	eval-rmse:2655.76
# [252]	train-rmse:2524.42	eval-rmse:2655.78
# [253]	train-rmse:2524.42	eval-rmse:2655.79
# [254]	train-rmse:2524.42	eval-rmse:2655.88
# [255]	train-rmse:2524.42	eval-rmse:2655.8
# [256]	train-rmse:2524.42	eval-rmse:2655.75
# [257]	train-rmse:2524.42	eval-rmse:2655.75
# [258]	train-rmse:2524.42	eval-rmse:2655.78
# [259]	train-rmse:2524.42	eval-rmse:2655.81
# [260]	train-rmse:2524.42	eval-rmse:2655.83
# [261]	train-rmse:2524.43	eval-rmse:2655.85
# [262]	train-rmse:2524.43	eval-rmse:2655.97
# [263]	train-rmse:2524.43	eval-rmse:2656.02
# [264]	train-rmse:2524.43	eval-rmse:2656.01
# [265]	train-rmse:2524.42	eval-rmse:2655.83
# [266]	train-rmse:2524.42	eval-rmse:2655.84
# [267]	train-rmse:2524.42	eval-rmse:2655.76
# [268]	train-rmse:2524.42	eval-rmse:2655.73
# [269]	train-rmse:2524.42	eval-rmse:2655.84
# [270]	train-rmse:2524.42	eval-rmse:2655.83
# [271]	train-rmse:2524.42	eval-rmse:2655.85
# [272]	train-rmse:2524.42	eval-rmse:2655.76
# [273]	train-rmse:2524.42	eval-rmse:2655.84
# [274]	train-rmse:2524.42	eval-rmse:2655.92
# [275]	train-rmse:2524.42	eval-rmse:2655.84
# [276]	train-rmse:2524.42	eval-rmse:2655.91
# [277]	train-rmse:2524.42	eval-rmse:2655.73
# [278]	train-rmse:2524.43	eval-rmse:2655.7
# [279]	train-rmse:2524.42	eval-rmse:2655.68
# [280]	train-rmse:2524.43	eval-rmse:2655.78
# [281]	train-rmse:2524.42	eval-rmse:2655.8
# [282]	train-rmse:2524.42	eval-rmse:2655.76
# [283]	train-rmse:2524.42	eval-rmse:2655.79
# [284]	train-rmse:2524.42	eval-rmse:2655.84
# [285]	train-rmse:2524.42	eval-rmse:2655.87
# [286]	train-rmse:2524.42	eval-rmse:2655.84
# [287]	train-rmse:2524.42	eval-rmse:2655.86
# [288]	train-rmse:2524.42	eval-rmse:2655.93
# [289]	train-rmse:2524.42	eval-rmse:2655.94
# [290]	train-rmse:2524.42	eval-rmse:2655.93
# [291]	train-rmse:2524.42	eval-rmse:2655.93
# [292]	train-rmse:2524.42	eval-rmse:2655.9
# [293]	train-rmse:2524.42	eval-rmse:2655.91
# [294]	train-rmse:2524.42	eval-rmse:2655.93
# [295]	train-rmse:2524.42	eval-rmse:2655.86
# [296]	train-rmse:2524.42	eval-rmse:2655.9
# [297]	train-rmse:2524.42	eval-rmse:2655.8
# [298]	train-rmse:2524.42	eval-rmse:2655.84
# [299]	train-rmse:2524.42	eval-rmse:2655.75

# %%
test[features].head()
# Out:
#    Year  Month  Day  DayOfWeek  WeekOfYear  StateHoliday
# 0  2015      9   17          3          38             0
# 1  2015      9   17          3          38             0
# 2  2015      9   17          3          38             0
# 3  2015      9   17          3          38             0
# 4  2015      9   17          3          38             0

# %% [markdown]
# ### making prediction for the hold out dataset

# %%
dtest = xgb.DMatrix(test[features])
test_probs = gbm.predict(dtest)

# %% [markdown]
# ##### Forecasted values for the test data

# %%
print(test_probs)
# Out:
# [6685.429  6685.429  6685.429  ... 6368.8457 6368.8457 6368.8457]

# %%
features = ['Year','Month','Day','DayOfWeek','WeekOfYear','StateHoliday','Sales']

# %%
train[features].head()
# Out:
#    Year  Month  Day  DayOfWeek  WeekOfYear  StateHoliday  Sales
# 0  2015      7   31          4          31             0   5263
# 1  2015      7   31          4          31             0   6064
# 2  2015      7   31          4          31             0   8314
# 3  2015      7   31          4          31             0  13995
# 4  2015      7   31          4          31             0   4822

# %%
train[features].to_csv('train.csv',index=False)

# %%
test[['Year','Month','Day','DayOfWeek','WeekOfYear','StateHoliday']].to_csv('test.csv',index=False)
